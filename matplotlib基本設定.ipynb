# %% [markdown]
# ## matplotlib 繪圖設定檔路徑
# #### matplotlib繪圖時，依據以下路徑順序尋找繪圖設定檔(matplotlibrc)位置，來進行繪圖相關屬性設定，如視圖視窗大小以及每英寸點數[dpi]，線條寬度，顏色和樣式，坐標軸，坐標和網格屬性，文本，字體等屬性。
# ```Python
# import matplotlib
# matplotlib.matplotlib_fname()
# ```

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\Lo yuan\\anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 12
plt.rcParams['font.family'] = 'Microsoft Yahei'

# %% [markdown]
# ## 查詢 matplotlib 的繪圖設定預設值 plt.rcParams

# %%
import matplotlib.pyplot as plt
plt.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': '.8',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %%
import matplotlib as mpl
mpl.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': '.8',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %% [markdown]
# #### 取得設定值
# - 字型（家族）：'font.family'
# - 字型：'font.sans-serif'
# - font.family：字型（家族）
# - font.sans-serif：字型
# - axes.prop_cycle：色彩循環

# %%
import matplotlib.pyplot as plt
print('字型（家族）', plt.rcParams['font.family'])
print('字型', plt.rcParams['font.sans-serif'])
print('解析度', plt.rcParams['figure.dpi'])
print('文字大小', plt.rcParams['font.size'])
print('配色', plt.rcParams['axes.prop_cycle'])
# Out:
# 字型（家族） ['sans-serif']
# 字型 ['Arial', 'Liberation Sans', 'DejaVu Sans', 'Bitstream Vera Sans', 'sans-serif']
# 解析度 100.0
# 文字大小 10.0
# 配色 cycler('color', ['#E24A33', '#348ABD', '#988ED5', '#777777', '#FBC15E', '#8EBA42', '#FFB5B8'])

# %% [markdown]
# #### 設定屬性值

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'jf-openhuninn-1.0'
plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 14
plt.rcParams['axes.prop_cycle'] = mpl.cycler(color=["r", "k", "c"])

# %% [markdown]
# #### 還原設定值

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# ## 繪圖樣式風格
# - plt.style.use(風格名稱)
# - 所有可用風格：https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.style.use('ggplot')#ggplot(跟R中的ggplot類似)
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
weight = [600,150,200,300,200,100,125,180]
height = [60,65,73,70,65,58,66,67]
plt.style.use('ggplot') #ggplot(跟R中的ggplot類似)
plt.scatter(weight, height)

# %% [markdown]
# ## 恢復預設參數設定
# ```Python
#     import matplotlib as mpl
#     mpl.rcdefaults() #恢復成 matplotlib 內建的樣式
#     mpl.rc_file_defaults() #恢復成最初導入的 rc 檔定義的樣式。
#
#     import matplotlib.pyplot as plt
#     plt.style.use('default')
# ```

# %% [markdown]
# ## 使用 seaborn style
# #### seaborn 預設有五種背景風格
# - darkgrid
# - dark
# - whitegrid
# - white
# - ticks

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.style.use('seaborn-whitegrid')
plt.bar(x, y)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16360\1346173518.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# <BarContainer object of 5 artists>

# %% [markdown]
# ## matplotlib 字型
# #### matplotlib 預設的字體以及所在位置，或新增字體存放路徑
# ```Python
# from matplotlib.font_manager import findfont, FontProperties
# findfont(FontProperties(family=FontProperties().get_family()))
# ```

# %%
from matplotlib.font_manager import findfont, FontProperties
findfont(FontProperties(family=FontProperties().get_family()))
# Out:
# 'C:\\Windows\\Fonts\\arial.ttf'

# %% [markdown]
# ## matplotlib 無法支援中文字型
# > ### 問題原因：matplotlib支援unicode編碼，無法顯示中文字
# > ### 解決方式：透過以下4種方法設定解決顯示中文字問題
#
#     1. 修改繪圖設定檔matplotlibrc
#     2. 動態修改繪圖設定檔
#         - plt.rcParams()
#         - plt.rc()
#     3. 動態載入系統中文字型
#     4. 自行新增字型

# %% [markdown]
# ### 修改繪圖設定檔matplotlibrc
# > 操作如下
# >> 1. 取得matplotlib繪圖設定檔路徑
#     ```python
#     import matplotlib
#     print(matplotlib.matplotlib_fname())
#     ```
# >> 2.  在matplotlib的繪圖設定檔尋找 *font.sans-serif*，位置添加字型名稱
#     - #font.sans-serif     : Bitstream Vera Sans, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif
# >> 3. 移除 "#"
# >> 4. 加入字型名稱
# >> 5.  設定檔修改存檔，關閉重啟Jupyter notebook

# %% [markdown]
# ### 動態修改繪圖設定檔
#
# - 動態修改繪圖設定檔 plt.rcParams
# >> 直接透過 plt.rcParams 動態設定 matplotlib繪圖設定檔，該設定只在繪圖當下改變設定值，程式結束後不會儲存。
#     ```python
#         import matplotlib.pyplot as plt
#
#         plt.rcParams['font.sans-serif'] #直接修改matplotlibrc設定檔中，'font.sans-serif'設定內容
#         plt.rcParams['axes.unicode_minus'] = False #解決座標軸負數的負號顯示問題
#     ```

# %%
# %pylab inline

plt.rcParams['font.sans-serif'] = 'Microsoft Yahei'  #用來正常顯示中文標籤，微軟雅黑體，['SimHei']
plt.rcParams['axes.unicode_minus'] = False #用來正常顯示正負號

x = np.linspace(-5,5,500)
y = power(e, x)

#frameon：邊框顯示
fig = plt.figure(figsize=(5,5), linewidth=10, edgecolor="red", frameon=True)
plt.plot(x, y, 'g--', lw=2, label='yoyo')
plt.legend(loc=0, fontsize=16)
plt.title('-5到5取500個點', fontsize=16)
plt.xlabel('-5到5數列', fontsize=16)
plt.ylabel(r'$e^x$', fontsize=16)
text(3, 7.5, r'$e^x$', fontsize=16)
#儲存圖片
fig.savefig("指數函數.png", edgecolor = fig.get_edgecolor())

# %%
# %pylab inline
import pandas as pd

plt.rcParams['font.sans-serif'] = 'SimHei'#'Microsoft YaHei'  #用來正常顯示中文標籤，微軟雅黑體，['SimHei']
plt.rcParams['axes.unicode_minus'] = False #用來正常顯示正負號
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.color'] = 'r'
plt.rcParams['figure.figsize'] = (10, 10)

x = pd.period_range("2017-06-01", periods = 200, freq = 'd')
x = x.to_timestamp().to_pydatetime() #to_pydatetime 是將 datetime64 轉 datetime
y = np.random.randn(200, 3).cumsum(0)# 產生三組，每組 200 個隨機常態分布元素

plt.plot(x, y)
plt.title('200 個隨機常態分布元素', fontsize = 16)
plt.xlabel('日期', fontsize = 16)
plt.ylabel('範圍', fontsize = 16)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 16)
#plt.savefig('sample.pdf')
savefig('sample.JPG', dpi = 200) #可以存PNG、JPG、EPS、SVG、PGF、PDF

# %% [markdown]
# - 動態修改繪圖設定檔 plt.rc
# >> 直接透過 plt.rc(類別, 設定值) 動態設定 matplotlib繪圖設定檔，該設定只在繪圖當下改變設定值，程式結束後不會儲存。
#     ```python
#         import matplotlib.pyplot as plt
#
#         font = {'family' : 'DFKai-SB',
#                 'weight' : 'bold',
#                 'size'  : '16'}
#         plt.rc('font', **font)              # 步驟一（設定字型的更多屬性）
#         plt.rc('axes', unicode_minus = False) # 步驟二（解決座標軸負數的負號顯示問題）
#     ```

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 1000)
y = np.sin(x)
z = np.cos(x**2)
plt.figure(figsize=(8, 4))
plt.plot(x, y, label = "$sin(x)$", color = "red", linewidth = 2)
plt.plot(x, z, "b--", label = "$cos(x^2)$")

#plt.rcParams['font.family'] = 'DFKai-SB'
font = {'family' : 'DFKai-SB',
        'weight' : 'bold',
        'size'  : '16'}
plt.rc('font', **font)              # 步驟一（設定字型的更多屬性）
plt.rc('axes', unicode_minus = False) # 步驟二（解決座標軸負數的負號顯示問題）
plt.xlabel("x軸")
plt.ylabel("y軸")
plt.title("標題")
plt.ylim(-1.2, 1.2)
plt.legend()
plt.show()

# %% [markdown]
# ##### 查尋 matplotlib已安裝字型
# ```Python
#     from matplotlib import font_manager
#     font_manager.findSystemFonts(fontpaths=None, fontext="ttf")
# ```

# %%
from matplotlib import font_manager
font_manager.findSystemFonts(fontpaths=None, fontext="ttf")
# Out:
# ['C:\\Windows\\Fonts\\MAIAN.TTF',
#  'C:\\Windows\\Fonts\\WINGDNG3.TTF',
#  'C:\\Windows\\Fonts\\timesbi.ttf',
#  'C:\\Windows\\Fonts\\ARIALN.TTF',
#  'C:\\Windows\\Fonts\\LBRITED.TTF',
#  'C:\\Windows\\Fonts\\Raleway-Regular.ttf',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
#  'C:\\Windows\\Fonts\\georgiab.ttf',
#  'C:\\Windows\\Fonts\\VLADIMIR.TTF',
#  'C:\\Windows\\Fonts\\DUBAI-LIGHT.TTF',
#  'C:\\Windows\\Fonts\\GILLUBCD.TTF',
#  'C:\\Windows\\Fonts\\POORICH.TTF',
#  'C:\\Windows\\Fonts\\SCRIPTBL.TTF',
#  'C:\\Windows\\Fonts\\HTOWERTI.TTF',
#  'C:\\Windows\\Fonts\\palabi.ttf',
#  'C:\\Windows\\Fonts\\CascadiaMono.ttf',
#  'C:\\Windows\\Fonts\\segoeuib.ttf',
#  'C:\\Windows\\Fonts\\CHILLER.TTF',
#  'C:\\Windows\\Fonts\\FRADMIT.TTF',
#  'C:\\Windows\\Fonts\\GOUDOS.TTF',
#  'C:\\Windows\\Fonts\\FREESCPT.TTF',
#  'C:\\Windows\\Fonts\\MEIRYOB.TTC',
#  'C:\\Windows\\Fonts\\seguili.ttf',
#  'C:\\Windows\\Fonts\\GARABD.TTF',
#  'C:\\Windows\\Fonts\\Inkfree.ttf',
# ...

# %% [markdown]
# ##### 查尋 matplotlib 可用字型
# ```Python
#     ### 法1
#     import matplotlib.font_manager
#     matplotlib.font_manager.fontManager.ttflist
#
#     ### 法2
#     from matplotlib.font_manager import fontManager
#     fontManager.ttflist
# ```

# %%
import matplotlib.font_manager
matplotlib.font_manager.fontManager.ttflist
fontlist = sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist])
for i in fontlist:
    print(i, end = '\t')
# Out:
# Agency FB	Agency FB	Algerian	Arial	Arial	Arial	Arial	Arial	Arial	Arial	Arial	Arial	Arial Rounded MT Bold	Arial Unicode MS	Arvo	Bahnschrift	Baskerville Old Face	Bauhaus 93	Bell MT	Bell MT	Bell MT	Berlin Sans FB	Berlin Sans FB	Berlin Sans FB Demi	Bernard MT Condensed	Blackadder ITC	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Book Antiqua	Book Antiqua	Book Antiqua	Book Antiqua	Bookman Old Style	Bookman Old Style	Bookman Old Style	Bookman Old Style	Bookshelf Symbol 7	Bradley Hand ITC	Britannic Bold	Broadway	Brush Script MT	Calibri	Calibri	Calibri	Calibri	Calibri	Calibri	Californian FB	Californian FB	Californian FB	Calisto MT	Calisto MT	Calisto MT	Calisto MT	Cambria	Cambria	Cambria	Cambria	Candara	Candara	Candara	Candara	Candara	Candara	Castellar	Centaur	Century	Century Gothic	Century Gothic	Century Gothic	Century Gothic	Century Schoolbook	Century Schoolbook	Century Schoolbook	Century Schoolbook	Chiller	Colonna MT	Comic San
# ...

# %% [markdown]
# ##### 找出系統適用的中文字體名稱
# #### 透過檔案大小大於 1M挑選，原因中文字用 2Byte 儲存要比英文字用 1Byte 來的大，中文字大於1MB
# #### 以os套件取得檔案大小
# > os.stat(檔案路徑).st_size
# > os.path.getsize(檔案路徑)
#
# ```Python
#     fontlist = [(f.name, f.fname) for f in fontManager.ttflist if os.path.exists(f.fname) and os.stat(f.fname).st_size>1e6]
#     pd.unique(fontlist).tolist()
# ```

# %%
from matplotlib.font_manager import fontManager
import pandas as pd
import os

fontlist = sorted([(f.name, f.fname) for f in fontManager.ttflist if os.path.exists(f.fname) and os.stat(f.fname).st_size>1e6])
pd.unique(fontlist).tolist()
# Out:
# [('Arial', 'C:\\Windows\\Fonts\\arial.ttf'),
#  ('Arial Unicode MS', 'C:\\Windows\\Fonts\\ARIALUNI.TTF'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibri.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrib.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrii.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibril.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrili.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibriz.ttf'),
#  ('Cambria', 'C:\\Windows\\Fonts\\cambria.ttc'),
#  ('DFKai-SB', 'C:\\Windows\\Fonts\\kaiu.ttf'),
#  ('Gabriola', 'C:\\Windows\\Fonts\\Gabriola.ttf'),
#  ('MS Gothic', 'C:\\Windows\\Fonts\\msgothic.ttc'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgun.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunbd.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunsl.ttf'),
#  ('Meiryo', 'C:\\Windows\\Fonts\\MEIRYO.TTC'),
#  ('Meiryo', 'C:\\Windows\\Fonts\\MEIRYOB.TTC'),
#  ('Microsoft JhengHei', 'C:\\Windows\\Fonts\\msjh.ttc'),
# ...

# %%
import matplotlib.font_manager
import os
set(sorted([(f.name, f.fname) for f in matplotlib.font_manager.fontManager.ttflist
                   if os.path.exists(f.fname) and os.stat(f.fname).st_size>1e6]))
# Out:
# {('Arial', 'C:\\Windows\\Fonts\\arial.ttf'),
#  ('Arial Unicode MS', 'C:\\Windows\\Fonts\\ARIALUNI.TTF'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibri.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrib.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrii.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibril.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrili.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibriz.ttf'),
#  ('Cambria', 'C:\\Windows\\Fonts\\cambria.ttc'),
#  ('DFKai-SB', 'C:\\Windows\\Fonts\\kaiu.ttf'),
#  ('Gabriola', 'C:\\Windows\\Fonts\\Gabriola.ttf'),
#  ('MS Gothic', 'C:\\Windows\\Fonts\\msgothic.ttc'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgun.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunbd.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunsl.ttf'),
#  ('Meiryo', 'C:\\Windows\\Fonts\\MEIRYO.TTC'),
#  ('Meiryo', 'C:\\Windows\\Fonts\\MEIRYOB.TTC'),
#  ('Microsoft JhengHei', 'C:\\Windows\\Fonts\\msjh.ttc'),
# ...

# %% [markdown]
# ##### 直接透過畫布顯示可用的中文字

# %%
from matplotlib.font_manager import fontManager
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings('ignore')

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
plt.subplots_adjust(0.04, 0.04, 0.99, 0.95, 0, 0)
plt.xticks([])
plt.yticks([])
x, y = 0.05, 0.18
fonts = [font.name for font in fontManager.ttflist if os.path.exists(font.fname) and os.stat(font.fname).st_size>1e6]
font = set(fonts)
dy = (1.0-y)/(len(fonts)/4 + (len(fonts)%4!=0))
for font in fonts:
    ax.text(x, y, font+" : 中文字體", {'fontname':font, 'fontsize':14}, transform=ax.transAxes)
    ax.text(x, y-dy/2, font, transform=ax.transAxes)
    x += 0.25
    if x >= 1.0:
        y += dy
        x = 0.05
ax.set_xlabel('X軸座標', {'fontname':'SimHei', 'fontsize':20})
ax.set_ylabel('Y軸座標', {'fontname':'SimHei', 'fontsize':20})
plt.show()
# Out:
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.

# %% [markdown]
# ### 動態載入系統中文字型

# %% [markdown]
# ### 1. 系統字型存放路徑
# - Windows：C:\Windows\Fonts\
# - Mac：/System/Library/Fonts
# - Linux：/usr/share/fonts
#
# ### 2. 取得所需字型檔(ttf、ttc) 完整路徑
# - Win7字型檔為ttf
# - Win8.1、Win10環境 ttf 要改為 ttc，msjh.ttc為微軟正黑體
#
# ### 3. 加入程式碼中
# ```Python
# import matplotlib.font_manager as fm
# font = fm.FontProperties(fname = r'C:\Windows\Fonts\msjh.ttc', size = 12)
# ```
#
# ### 依作業系統處理中文字顯示
# ```Python
#     import platform
#     import matplotlib.font_manager as fm
#     plt.rcParams['axes.unicode_minus'] = False #用來正常顯示正負號
#
#     #依據作業系統設定字型
#     sysstr = platform.system()
#     if(sysstr =="Windows"):
#         if (platform.release == '7'):
#             plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
#         elif (platform.release == '8' or platform.release == '8.1'):
#             plt.rcParams['font.sans-serif'] = 'SimHei'
#             font = fm.FontProperties(fname = r'C:\Windows\Fonts\msjh.ttc', size = 20)
#         else:
#             plt.rcParams['font.sans-serif'] = 'SimHei'
#             font = fm.FontProperties(fname = r'C:\Windows\Fonts\msjh.ttc', size = 20)
#     elif(sysstr == "Linux"):
#         print ("Linux")
#     elif(sysstr == "Darwin"):
#         print ("Mac os")
#     else:
#         print ("其他系統")
# ```

# %%
from matplotlib.font_manager import FontProperties
font = FontProperties(fname = r'C:\Windows\Fonts\mingliub.ttf', size = 12)

# %% [markdown]
# ### 自行新增字型
#
# ### 方法1：將字型新增到 matplotlib 可用字型的列表中（僅在程式執行時有效）
# matplotlib.font_manager.fontManager.addfont(字型路徑)
# ```Python
# ### 安裝wget
# !pip install wget
#
# ### 下載TaipeiSansTCBeta-Regular (3).ttf
# !python -m wget "https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download"
#
# ### 加入字型
#
# ```Python
# import matplotlib as mpl
# from matplotlib import font_manager
# font_path = 'TaipeiSansTCBeta-Regular.ttf'
# prop = font_manager.FontProperties(fname=font_path)
# mpl.rc('font', family=prop.get_name())
#
# 或
#
# import matplotlib as mpl
# from matplotlib import font_manager
# font_path = 'TaipeiSansTCBeta-Regular.ttf'
# font_manager.fontManager.addfont(font_path)
# mpl.rc('font', family='Taipei Sans TC Beta')
# ```

# %%
# !pip install wget

# %%
# !python -m wget "https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download"
# Out:
# Saved under TaipeiSansTCBeta-Regular (1).ttf

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager
font_path = 'C:\\Users\\Lo yuan\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansTC-Regular.ttf'
prop = font_manager.FontProperties(fname=font_path)
prop.get_name()
# Out:
# 'Noto Sans TC'

# %%
import matplotlib as mpl
from matplotlib import font_manager
font_path = 'TaipeiSansTCBeta-Regular.ttf'
prop = font_manager.FontProperties(fname=font_path)
mpl.rc('font', family=prop.get_name())

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt 
from matplotlib.font_manager import fontManager
import numpy as np

#plt.style.use('seaborn') 
fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
fig, ax = plt.subplots()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal') # X軸、Y軸等長設定

ax.set_xlabel('X軸')
ax.set_ylabel('Y軸')
ax.annotate('區域最大值', 
        xy=(6.28, 1), 
        xytext=(10, 4),
        arrowprops=dict(facecolor='black', shrink=0.05))

# %% [markdown]
# ### 方法2
# 1. 安裝完新字型後，將以下路徑資料夾中 fontlist-vxxx.json 的相關快取（cache）檔案都刪除。
# 2. 重新啟動此程式、列出字型，matplotlib 即會自動新增 fontlist-vxxx.json 快取檔案，即可使用新字型。
# ```Python
#     import matplotlib as mpl
#     mpl.get_cachedir()
# ```

# %% [markdown]
# ## matplotlib色彩映射、調色盤
# ### 色彩映射RGB數值
# ```Python
#     import matplotlib.pyplot as plt
#     plt.cm.datad
# ```
# ### 色彩名稱映射列表
# ```Python
#     import matplotlib.pyplot as plt
#     if mpl.__version__ >= '1.5.0':
#         print(plt.colormaps())
#     elif mpl.__version__ < '1.5.0':
#         print(plt.cm.cmap_d.keys())
# ```

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

#色彩名稱映射列表
if mpl.__version__ >= '1.5.0':
    print(plt.colormaps())
elif mpl.__version__ < '1.5.0':    
    print(plt.cm.cmap_d.keys())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(4,0.4))
#col_map = plt.get_cmap(plt.colormaps()[0])
col_map = plt.get_cmap('tab10_r')
mpl.colorbar.ColorbarBase(ax, cmap=col_map, orientation = 'horizontal')
plt.show()

# %%
#忽略以_r結尾的型別，因為它們都是型別後面不帶有_r的反轉版本(reversed version)
[m for m in plt.cm.datad if not m.endswith("_r")]
# Out:
# ['Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
#  'Set1',
#  'Set2',
#  'Set3',
#  'tab10',
#  'tab20',
#  'tab20b',
#  'tab20c']

# %% [markdown]
# ### 色彩空間轉換庫
# ```Python
#     !pip install colorspacious
# ```

# %%
# !pip install colorspacious

# %% [markdown]
# ### 色彩映射顯示1

# %%
#https://matplotlib.org/stable/tutorials/colors/colormaps.html
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from colorspacious import cspace_converter
cmaps = {}

gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

def plot_color_gradients(category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows - 1) * 0.1) * 0.22
    fig, axs = plt.subplots(nrows=nrows + 1, figsize=(6.4, figh))
    fig.subplots_adjust(top=1 - 0.35 / figh, bottom=0.15 / figh,
                        left=0.2, right=0.99)
    axs[0].set_title(f'{category} colormaps', fontsize=14)

    for ax, name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        ax.text(-0.01, 0.5, name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()

    # Save colormap list for later.
    cmaps[category] = cmap_list
    
plot_color_gradients('Perceptually Uniform Sequential',
                     ['viridis', 'plasma', 'inferno', 'magma', 'cividis'])

# %% [markdown]
# ### 色彩映射顯示2

# %%
#https://www.osgeo.cn/matplotlib/tutorials/colors/colormaps.html
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from colorspacious import cspace_converter
from collections import OrderedDict

cmaps = OrderedDict()

#順序
cmaps['Perceptually Uniform Sequential'] = [
            'viridis', 'plasma', 'inferno', 'magma', 'cividis']
cmaps['Sequential'] = [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']
#順序2
cmaps['Sequential (2)'] = [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']
#發散
cmaps['Diverging'] = [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']
#循環
cmaps['Cyclic'] = ['hsv']
#'twilight', 'twilight_shifted'
#定性
cmaps['Qualitative'] = ['Pastel1', 'Pastel2', 'Paired', 'Accent',
                        'Dark2', 'Set1', 'Set2', 'Set3',
                        'tab10', 'tab20', 'tab20b', 'tab20c']
#雜項
cmaps['Miscellaneous'] = [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg', 'gist_rainbow', 'rainbow']
#'jet', 'turbo', 'nipy_spectral','gist_ncar'



nrows = max(len(cmap_list) for cmap_category, cmap_list in cmaps.items())
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

def plot_color_gradients(cmap_category, cmap_list, nrows):
    fig, axes = plt.subplots(nrows=nrows)
    fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)
    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, name in zip(axes, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        pos = list(ax.get_position().bounds)
        x_text = pos[0] - 0.01
        y_text = pos[1] + pos[3]/2.
        fig.text(x_text, y_text, name, va='center', ha='right', fontsize=10)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axes:
        ax.set_axis_off()


for cmap_category, cmap_list in cmaps.items():
    plot_color_gradients(cmap_category, cmap_list, nrows)

plt.show()

# %% [markdown]
# ### 色彩映射顯示3

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

def plot_colorMaps(cmap):
    fig, ax = plt.subplots(figsize=(4,0.4))
    col_map = plt.get_cmap(cmap)
    mpl.colorbar.ColorbarBase(ax, cmap=col_map, orientation = 'horizontal')

    plt.show()

for cmap_id in plt.colormaps():
    print(cmap_id)
    plot_colorMaps(cmap_id)
# Out:
# magma
# inferno
# plasma
# viridis
# cividis
# twilight
# twilight_shifted
# turbo
# Blues
# BrBG
# BuGn
# BuPu
# CMRmap
# GnBu
# Greens
# Greys
# OrRd
# Oranges
# PRGn
# PiYG
# PuBu
# PuBuGn
# PuOr
# PuRd
# Purples
# RdBu
# RdGy
# RdPu
# RdYlBu
# RdYlGn
# Reds
# Spectral
# Wistia
# YlGn
# YlGnBu
# YlOrBr
# YlOrRd
# afmhot
# autumn
# binary
# bone
# brg
# bwr
# cool
# coolwarm
# copper
# cubehelix
# flag
# gist_earth
# gist_gray
# gist_heat
# gist_ncar
# gist_rainbow
# gist_stern
# gist_yarg
# gnuplot
# gnuplot2
# gray
# hot
# hsv
# jet
# nipy_spectral
# ocean
# pink
# prism
# rainbow
# seismic
# spring
# summer
# terrain
# winter
# Accent
# Dark2
# Paired
# Pastel1
# Pastel2
# Set1
# Set2
# Set3
# tab10
# tab20
# tab20b
# tab20c
# magma_r
# inferno_r
# plasma_r
# viridis_r
# cividis_r
# twilight_r
# twilight_shifted_r
# turbo_r
# Blues_r
# BrBG_r
# BuGn_r
# BuPu_r
# CMRmap_r
# GnBu_r
# Greens_r
# Greys_r
# OrRd_r
# Oranges_r
# PRGn_r
# PiYG_r
# PuBu_r
# PuBuGn_r
# PuOr_r
# PuRd_r
# ...

# %% [markdown]
# ### 色彩循環 axes.prop_cycle
# ```Python
#     import matplotlib.pyplot as plt
#     import matplotlib as mpl
#     mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color = plt.cm.datad['BrBG'][5:])
# ```

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# Set the default color cycle
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color = plt.cm.datad['BuPu'][5:])

x = np.linspace(0, 20, 100)

fig, axes = plt.subplots(nrows=2)

for i in range(15):
    axes[0].plot(x, i * (x - 10)**2)

for i in range(15):
    axes[1].plot(x, i * np.cos(x))

plt.show()

# %%
from cycler import cycler
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Define a list of markevery cases and color cases to plot
cases = [None,
         8,
         (30, 8),
         [16, 24, 30],
         [0, -1],
         slice(100, 200, 3),
         0.1,
         0.3,
         1.5,
         (0.0, 0.1),
         (0.45, 0.1)]

colors = ['#1f77b4',
          '#ff7f0e',
          '#2ca02c',
          '#d62728',
          '#9467bd',
          '#8c564b',
          '#e377c2',
          '#7f7f7f',
          '#bcbd22',
          '#17becf',
          '#1a55FF']

# Configure rcParams axes.prop_cycle to simultaneously cycle cases and colors.
mpl.rcParams['axes.prop_cycle'] = cycler(markevery=cases, color=colors)

# Create data points and offsets
x = np.linspace(0, 2 * np.pi)
offsets = np.linspace(0, 2 * np.pi, 11, endpoint=False)
yy = np.transpose([np.sin(x + phi) for phi in offsets])

# Set the plot curve with markers and a title
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.6, 0.75])

for i in range(len(cases)):
    ax.plot(yy[:, i], marker='o', label=str(cases[i]))
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.title('Support for axes.prop_cycle cycler with markevery')

plt.show()
